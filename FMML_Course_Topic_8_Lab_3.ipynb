# %% [markdown]
# <a href="https://colab.research.google.com/github/Roshini1717/fmmllab/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-05 03:29:19--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   176MB/s    in 0.4s
#
# 2024-04-05 03:29:22 (176 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5478    1406.5291v3  We propose a Generalized Dantzig Selector (GDS...  stat
# 9881    1212.3618v2  We present ML4PG - a machine learning extensio...    cs
# 7849   1803.08118v1  Seglearn is an open-source python package for ...  stat
# 20724  1611.06108v1  In this paper we present an algorithm to build...    cs
# 15974  1607.06852v1  In this paper, we present a novel approach to ...    cs
# ...             ...                                                ...   ...
# 21865   1402.2148v1  Practical model building processes are often t...  stat
# 29715  1710.02820v1  Micro-expressions are rapid and involuntary fa...    cs
# 15079   1401.7077v4  We measured entropy and symbolic diversity for...    cs
# 12502  1802.06095v1  Time-series data is being increasingly collect...  stat
# 22681  1704.02578v2  We study strictly proper scoring rules in the ...  stat
#
#                                                    title  year  \
# 5478   Generalized Dantzig Selector: Application to t...  2014
# 9881   Machine Learning in Proof General: Interfacing...  2012
# 7849   Seglearn: A Python Package for Learning Sequen...  2018
# 20724  Navigational Rule Derivation: An algorithm to ...  2016
# 15974  CFGs-2-NLU: Sequence-to-Sequence Learning for ...  2016
# ...                                                  ...   ...
# 21865  An Algorithmic Framework for Computing Validat...  2014
# 29715             Micro-Expression Spotting: A Benchmark  2017
# 15079  Quantifying literature quality using complexit...  2014
# 12502  Mining Sub-Interval Relationships In Time Seri...  2018
# 22681  Strictly Proper Kernel Scoring Rules and Diver...  2017
#
#                                                 keywords
# 5478   [generalized, parameter, structure, leveraged,...
# 9881   [extension, statistics, sequences, structures,...
# 7849   [sequences, segmentation, implementation, clas...
# 20724  [algorithm, forbidden, interpretation, classif...
# 15974  [understanding, conjunction, specifically, app...
# ...                                                  ...
# 21865  [practical, processes, consuming, different, v...
# 29715  [expressions, involuntary, expressions, suppre...
# 15079  [diversity, including, literature, laureates, ...
# 12502  [increasingly, collected, neuroscience, transp...
# 22681  [reproducing, associated, divergence, conditio...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5478     [generalized, parameter, structure, leveraged,...
# 9881     [extension, statistics, sequences, structures,...
# 7849     [sequences, segmentation, implementation, clas...
# 20724    [algorithm, forbidden, interpretation, classif...
# 15974    [understanding, conjunction, specifically, app...
#                                ...
# 11352    [introduce, principal, differences, analyzing,...
# 34116    [automatic, summarization, centrality, relevan...
# 7096     [comparing, traditional, criterion, nonlinear,...
# 2093     [physiological, variation, diagnosed, conditio...
# 21674    [algorithm, classifier, approximation, schapir...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8847 words.
# Out of those 4629 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="feed23ac-76f4-4cd7-bc77-bf885f1e4c4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("feed23ac-76f4-4cd7-bc77-bf885f1e4c4c")) {                    Plotly.newPlot(                        "feed23ac-76f4-4cd7-bc77-bf885f1e4c4c",                        [{"x":["framework","encompassing","inapplicable","generalized","guarantee","asymptotic","efficient","probability","investigate","theoretical","parameter","conjugate","leveraged","experimental","statistical","estimation","structure","application","established","computational","automated","sequences","available","development","interactive","interfacing","statistics","algorithms","extension","clustering","interfaces","structures","clustered","libraries","implementation","compatible","distributed","segmentation","regression","forecasting","classification","contextual","documentation","multivariate","description","derivation","determining","navigational","algorithm","classified","navigation","interpretation","forbidden","generalize","commercial","visibility","determine","simulating","elaboration","environments","demonstrate","information","evaluation","pragmatics","grammatical","accordingly","considerations","semantics","developed","nonterminal","attributed","translates","critically","associated","specifically","understanding","annotated","recurrent","conversational","conversation","utterances","arbitrary","conjunction","utterance","explicitly","annotation","expansions","knowledge","translate","pragmatic","performing","technique","representation","mechanism","benchmarks","implement","satisfies","synthesis","reduction","computation","utilizing","generation","experiments","specification","skeletons","connected","smoothing","prominent","arrangement","qualities","coordinate","articulations","properties","recognition","instability","differences","resulting","curvature","successful","viewpoint","similarities","invariant","therefore","increasing","correspond","descriptions","traditional","perceptual","extracted","complexity","comparing","depending","existence","dynamical","particular","behaviors","different","approaching","corresponding","parametrized","landscapes","suggesting","numerically","architectures","distinctive","increasingly","landscape","directions","exploitation","exploration","approximations","performance","empirical","minimization","effectiveness","efficiently","empirically","negatively","balancing","outperforms","optimally","recommend","unstructured","continually","attributes","challenges","experience","architecture","retailers","quantitative","recommender","personalisation","multitude","catalogue","consistent","methodology","recommendations","implemented","characterisation","foundational","improvement","evaluating","inconsistent","processes","difficult","integrated","dimensions","consequently","developers","aggregate","uncertain","determinants","especially","generated","characteristics","candidate","stakeholders","continuous","facilitate","government"],"y":[519,3,4,66,35,20,407,157,143,141,131,9,8,390,148,210,348,248,45,278,83,93,303,138,46,3,64,581,80,145,14,121,15,4,128,17,92,214,105,14,514,52,7,25,55,7,30,3,826,29,31,53,2,52,31,12,73,11,3,88,534,732,262,2,17,21,9,112,220,3,12,9,6,108,149,151,70,140,17,16,9,71,24,7,80,64,2,341,14,3,74,261,363,114,97,65,15,45,89,138,43,151,599,16,8,81,15,19,6,8,21,2,202,361,7,76,149,12,71,18,35,66,144,100,34,40,169,21,119,234,66,44,33,21,271,18,750,4,128,6,8,14,14,131,10,45,10,40,20,51,42,879,147,57,223,137,89,5,14,263,16,3,28,3,63,102,33,249,0,73,17,1,6,0,79,74,26,113,5,1,165,46,14,103,146,64,40,30,8,24,33,3,117,169,101,49,2,119,51,6],"type":"bar"},{"x":["framework","encompassing","inapplicable","generalized","guarantee","asymptotic"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4629,), (4629, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8158333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>VRFP</span> <span style=''>On</span> <span style=''>the</span> <span style=''>fly</span> <span style=''>Video</span> <span style='background-color:rgba(0, 255, 0, 0.5901639344262295);'>Retrieval</span> <span style=''>using</span> <span style=''>Web</span> <span style=''>Images</span> <span style=''>and</span> <span style=''>Fast</span> <span style=''>Fisher</span> <span style=''>Vector</span> <span style=''>Products</span> <br/><br/><span style=''>VRFP</span> <span style=''>is</span> <span style=''>a</span> <span style=''>real</span> <span style=''>time</span> <span style=''>video</span> <span style='background-color:rgba(0, 255, 0, 0.5901639344262295);'>retrieval</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>based</span> <span style=''>on</span> <span style=''>short</span> <span style=''>text</span> <span style=''>input</span> <span style=''>queries</span> <span style=''>which</span> <span style=''>obtains</span> <span style=''>weakly</span> <span style=''>labeled</span> <span style=''>training</span> <span style=''>images</span> <span style=''>from</span> <span style=''>the</span> <span style=''>web</span> <span style=''>after</span> <span style=''>the</span> <span style=''>query</span> <span style=''>is</span> <span style=''>known</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.4117647058823529);'>retrieved</span> <span style=''>web</span> <span style=''>images</span> <span style='background-color:rgba(0, 255, 0, 0.5398230088495575);'>representing</span> <span style=''>the</span> <span style=''>query</span> <span style=''>and</span> <span style=''>each</span> <span style=''>database</span> <span style=''>video</span> <span style=''>are</span> <span style=''>treated</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>unordered</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collections</span> <span style=''>of</span> <span style=''>images</span> <span style=''>and</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>collection</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.305785123966942);'>represented</span> <span style=''>using</span> <span style=''>a</span> <span style=''>single</span> <span style=''>Fisher</span> <span style=''>Vector</span> <span style=''>built</span> <span style=''>on</span> <span style=''>CNN</span> <span style=''>features</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>show</span> <span style=''>that</span> <span style=''>a</span> <span style=''>Fisher</span> <span style=''>Vector</span> <span style=''>is</span> <span style=''>robust</span> <span style=''>to</span> <span style=''>noise</span> <span style=''>present</span> <span style=''>in</span> <span style=''>web</span> <span style=''>images</span> <span style=''>and</span> <span style=''>compares</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>favorably</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>accuracy</span> <span style=''>to</span> <span style=''>other</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.36144578313253006);'>representations</span> <span style=''>While</span> <span style=''>a</span> <span style=''>Fisher</span> <span style=''>Vector</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constructed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>for</span> <span style=''>a</span> <span style=''>new</span> <span style=''>query</span> <span style=''>matching</span> <span style=''>against</span> <span style=''>the</span> <span style=''>test</span> <span style=''>set</span> <span style=''>is</span> <span style=''>slow</span> <span style=''>due</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Model</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>mixture</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminant</span> <span style=''>analysis</span> <span style=''>with</span> <span style=''>hidden</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>for</span> <span style=''>curve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>modeling</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presenting</span> <span style=''>regime</span> <span style=''>changes</span> <span style=''>over</span> <span style=''>time</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>model</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>mixture</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>discriminant</span> <span style=''>analysis</span> <span style=''>approach</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>specific</span> <span style=''>hidden</span> <span style=''>process</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>model</span> <span style=''>that</span> <span style=''>governs</span> <span style=''>the</span> <span style=''>regime</span> <span style=''>changes</span> <span style=''>over</span> <span style=''>time</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particularly</span> <span style=''>adapted</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>complex</span> <span style=''>shaped</span> <span style=''>classes</span> <span style=''>of</span> <span style=''>curves</span> <span style=''>where</span> <span style=''>each</span> <span style=''>class</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potentially</span> <span style=''>composed</span> <span style=''>of</span> <span style=''>several</span> <span style=''>sub</span> <span style=''>classes</span> <span style=''>and</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>the</span> <span style=''>regime</span> <span style=''>changes</span> <span style=''>within</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>homogeneous</span> <span style=''>sub</span> <span style=''>class</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>integrates</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>heterogeneity</span> <span style=''>of</span> <span style=''>each</span> <span style=''>class</span> <span style=''>of</span> <span style=''>curves</span> <span style=''>via</span> <span style=''>a</span> <span style=''>mixture</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>and</span> <span style=''>the</span> <span style=''>regime</span> <span style=''>changes</span> <span style=''>within</span> <span style=''>each</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Online</span> <span style=''>Learning</span> <span style=''>in</span> <span style=''>Case</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.4666666666666667);'>Unbounded</span> <span style=''>Losses</span> <span style=''>Using</span> <span style=''>the</span> <span style=''>Follow</span> <span style='background-color:rgba(255, 0, 0, 0.3913043478260869);'>Perturbed</span> <span style=''>Leader</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>expert</span> <span style=''>advice</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considered</span> <span style=''>for</span> <span style=''>the</span> <span style=''>case</span> <span style=''>where</span> <span style=''>losses</span> <span style=''>of</span> <span style=''>experts</span> <span style=''>suffered</span> <span style=''>at</span> <span style=''>each</span> <span style=''>step</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>bounded</span> <span style=''>in</span> <span style=''>advance</span> <span style=''>We</span> <span style=''>present</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modification</span> <span style=''>of</span> <span style=''>Kalai</span> <span style=''>and</span> <span style=''>Vempala</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>following</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3913043478260869);'>perturbed</span> <span style=''>leader</span> <span style=''>where</span> <span style=''>weights</span> <span style=''>depend</span> <span style=''>on</span> <span style=''>past</span> <span style=''>losses</span> <span style=''>of</span> <span style=''>the</span> <span style=''>experts</span> <span style=''>New</span> <span style=''>notions</span> <span style=''>of</span> <span style=''>a</span> <span style=''>volume</span> <span style=''>and</span> <span style=''>a</span> <span style=''>scaled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fluctuation</span> <span style=''>of</span> <span style=''>a</span> <span style=''>game</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>protected</span> <span style=''>from</span> <span style=''>unrestrictedly</span> <span style=''>large</span> <span style=''>one</span> <span style=''>step</span> <span style=''>losses</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>has</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>when</span> <span style=''>the</span> <span style=''>scaled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fluctuations</span> <span style=''>of</span> <span style=''>one</span> <span style=''>step</span> <span style=''>losses</span> <span style=''>of</span> <span style=''>experts</span> <span style=''>of</span> <span style=''>the</span> <span style=''>pool</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>zero</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>metboost</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Exploratory</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>analysis</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustered</span> <span style=''>data</span> <br/><br/><span style=''>As</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collections</span> <span style=''>become</span> <span style=''>larger</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploratory</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>analysis</span> <span style=''>becomes</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>but</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>When</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchically</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustered</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>even</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>because</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>with</span> <span style=''>mixed</span> <span style=''>effect</span> <span style=''>models</span> <span style=''>can</span> <span style=''>produce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>misleading</span> <span style=''>results</span> <span style=''>when</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>effects</span> <span style=''>are</span> <span style=''>not</span> <span style=''>included</span> <span style=''>into</span> <span style=''>the</span> <span style=''>model</span> <span style=''>(Bauer</span> <span style=''>and</span> <span style=''>Cai</span> <span style=''>2009)</span> <span style=''>A</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>method</span> <span style=''>called</span> <span style=''>boosted</span> <span style=''>decision</span> <span style=''>trees</span> <span style=''>(Friedman</span> <span style=''>2001)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>good</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploratory</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>analysis</span> <span style=''>in</span> <span style=''>real</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>because</span> <span style=''>it</span> <span style=''>can</span> <span style=''>detect</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictors</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style=''>effects</span> <span style=''>while</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accounting</span> <span style=''>for</span> <span style=''>missing</span> <span style=''>data</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>to</span> <span style=''>boosted</span> <span style=''>decision</span> <span style=''>decision</span> <span style=''>trees</span> <span style=''>called</span> <span style=''>metboost</span> <span style=''>for</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.1072838177251525)
# 	representation (0.1302475780409042)
# 	architecture (0.08934337997847147)
# 	segmentation (0.07678507355579477)
# 	experimental (0.13993541442411195)
# 	information (0.26264800861141013)
# 	detection (0.12558306422676713)
# 	recognition (0.12952996053103696)
# 	different (0.2691065662002153)
# 	convolutional (0.13814137064944385)
#
# Some Statistics words are:
# 	stochastic (0.12816691505216096)
# 	algorithm (0.3869846000993542)
# 	estimation (0.16741182314952807)
# 	distribution (0.18132141082960754)
# 	variables (0.13909587680079483)
# 	statistical (0.16045702930948832)
# 	theoretical (0.15896671634376552)
# 	dimensional (0.1927471435668157)
# 	inference (0.19870839542970692)
# 	regression (0.18181818181818182)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d9ce6673-2500-47de-84bc-b33b4b82ab7f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9ce6673-2500-47de-84bc-b33b4b82ab7f")) {                    Plotly.newPlot(                        "d9ce6673-2500-47de-84bc-b33b4b82ab7f",                        [{"x":["framework","encompassing","inapplicable","generalized","guarantee","asymptotic","efficient","probability","investigate","theoretical","parameter","conjugate","leveraged","experimental","statistical","estimation","structure","application","established","computational","automated","sequences","available","development","interactive","interfacing","statistics","algorithms","extension","clustering","interfaces","structures","clustered","libraries","implementation","compatible","distributed","segmentation","regression","forecasting","classification","contextual","documentation","multivariate","description","derivation","determining","navigational","algorithm","classified","navigation","interpretation","forbidden","generalize","commercial","visibility","determine","simulating","elaboration","environments","demonstrate","information","evaluation","pragmatics","grammatical","accordingly","considerations","semantics","developed","nonterminal","attributed","translates","critically","associated","specifically","understanding","annotated","recurrent","conversational","conversation","utterances","arbitrary","conjunction","utterance","explicitly","annotation","expansions","knowledge","translate","pragmatic","performing","technique","representation","mechanism","benchmarks","implement","satisfies","synthesis","reduction","computation","utilizing","generation","experiments","specification","skeletons","connected","smoothing","prominent","arrangement","qualities","coordinate","articulations","properties","recognition","instability","differences","resulting","curvature","successful","viewpoint","similarities","invariant","therefore","increasing","correspond","descriptions","traditional","perceptual","extracted","complexity","comparing","depending","existence","dynamical","particular","behaviors","different","approaching","corresponding","parametrized","landscapes","suggesting","numerically","architectures","distinctive","increasingly","landscape","directions","exploitation","exploration","approximations","performance","empirical","minimization","effectiveness","efficiently","empirically","negatively","balancing","outperforms","optimally","recommend","unstructured","continually","attributes","challenges","experience","architecture","retailers","quantitative","recommender","personalisation","multitude","catalogue","consistent","methodology","recommendations","implemented","characterisation","foundational","improvement","evaluating","inconsistent","processes","difficult","integrated","dimensions","consequently","developers","aggregate","uncertain","determinants","especially","generated","characteristics","candidate","stakeholders","continuous","facilitate","government","comprehensive","subjective","uncertainty","scenarios","illustrated","efficiency","combination","prototype","challenging","reasoning","necessary","difficulties","evidential","formalize","graphical","molecules","applicable","projections","literature","specified","represented","projection","relational","assumptions","distributions","including","factorizations","furthermore","undirected","applications","infectious","projected","complicated","independence","fundamental","conditioned","essential","instances","invariances","variables","functions","compactly","distribution","independencies","mathematical","unsupervised","initialising","variational","contribution","important","strengths","unlabeled","supervised","generative","extra ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	retailers
# 	catalogue
# 	infectious
# 	initialising
# 	beginnings
# 	statistician
# 	econometrics
# 	noticeably
# 	uncharted
# 	retention
# 	uncorrelated
# 	reweighting
# 	ergodicity
# 	idealized
# 	quadrature
# 	integrand
# 	tempering
# 	counteracts
# 	barycenter
# 	barycenters
# Some words which never appear in Statistics papers:
# 	navigational
# 	forbidden
# 	elaboration
# 	pragmatics
# 	grammatical
# 	nonterminal
# 	conversational
# 	utterances
# 	utterance
# 	skeletons
# 	articulations
# 	evidential
# 	watershed
# 	panchromatic
# 	angiography
# 	suppression
# 	cambridge
# 	congressional
# 	discourse
# 	transcripts

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.077017754392443e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.765
